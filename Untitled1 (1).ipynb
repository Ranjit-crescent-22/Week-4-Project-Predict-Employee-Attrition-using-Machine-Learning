# %% [markdown]
# # 🧠 Employee Attrition Prediction
#
# Predict whether an employee is likely to leave the company using HR data. This helps HR take proactive steps to retain talent.

# %% [markdown]
# ## 📥 Step 1: Load the Dataset
#
# We upload the IBM HR dataset and load it using pandas to preview its structure and contents.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e59d3977-9c50-42bb-8182-676d1092ee1d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e59d3977-9c50-42bb-8182-676d1092ee1d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## 🔍 Step 2: Explore the Data
#
# We examine column types, null values, and key features like `Attrition`, `JobRole`, and `OverTime` to understand the data.

# %%
import pandas as pd

# Load data
df = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# Preview
print("Shape:", df.shape)
print("Columns:", df.columns.tolist())
df.head()
# Out:
# Shape: (1470, 35)
# Columns: ['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# ...

# %%
# Basic info
df.info()
df.describe()

# Check target distribution
df['Attrition'].value_counts()

# Look at key categorical columns
df['JobRole'].value_counts()
df['OverTime'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# ## 🧹 Step 3: Data Cleaning & Preprocessing
#
# - Drop unused columns like `EmployeeNumber`
# - Encode categorical features using OneHotEncoding
# - Scale numerical features using StandardScaler
# - Handle class imbalance using SMOTE

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE

# Load dataset
df = pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")

# Drop unnecessary columns
df = df.drop(['EmployeeCount', 'EmployeeNumber', 'Over18', 'StandardHours'], axis=1)

# Encode target column
df['Attrition'] = df['Attrition'].map({'Yes': 1, 'No': 0})

# One-Hot Encode categorical columns
cat_cols = df.select_dtypes(include='object').columns
df = pd.get_dummies(df, columns=cat_cols, drop_first=True)

# Separate features and target
X = df.drop('Attrition', axis=1)
y = df['Attrition']

# Scale numerical features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply SMOTE to handle class imbalance
sm = SMOTE(random_state=42)
X_resampled, y_resampled = sm.fit_resample(X_scaled, y)

# Final shape after resampling
print("Original target value counts:\n", y.value_counts())
print("\nAfter SMOTE target value counts:\n", pd.Series(y_resampled).value_counts())
# Out:
# Original target value counts:
#  Attrition
# 0    1233
# 1     237
# Name: count, dtype: int64
#
# After SMOTE target value counts:
#  Attrition
# 1    1233
# 0    1233
# Name: count, dtype: int64

# %% [markdown]
# ## 📊 Step 4: Exploratory Data Analysis (EDA)
#
# We use visualizations to discover patterns in attrition based on salary, department, and overtime status.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Correlation heatmap
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(), cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# Attrition count
sns.countplot(x='Attrition', data=pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv'))
plt.title("Attrition Count")
plt.show()

# Boxplot: MonthlyIncome vs Attrition
sns.boxplot(x='Attrition', y='MonthlyIncome', data=pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv'))
plt.title("Income vs Attrition")
plt.show()

# %% [markdown]
# ## 🤖 Step 5: Build ML Models
#
# Train three models — Logistic Regression, Random Forest, and XGBoost — using the processed data.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split, cross_val_score

# Use the correct variable names
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# Models
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "Random Forest": RandomForestClassifier(),
    "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric='logloss')
}

# Train and cross-validate
for name, model in models.items():
    scores = cross_val_score(model, X_train, y_train, cv=5, scoring='recall')
    print(f"{name} - Recall Score: {scores.mean():.4f}")
# Out:
# Logistic Regression - Recall Score: 0.8200
# Random Forest - Recall Score: 0.9090
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [15:43:12] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [15:43:12] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [15:43:13] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:158: UserWarning: [15:43:13] WARNING: /workspace/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# ...

# %% [markdown]
# ## 📈 Step 6: Evaluate Model Performance
#
# We evaluate accuracy, recall, precision, F1-score, and confusion matrix. Recall is our main focus to catch employees likely to leave.

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Pick best model (example: Random Forest)
model = RandomForestClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# Evaluation
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[241   9]
#  [ 20 224]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94       250
#            1       0.96      0.92      0.94       244
#
#     accuracy                           0.94       494
#    macro avg       0.94      0.94      0.94       494
# weighted avg       0.94      0.94      0.94       494

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Predict on test set
y_pred = model.predict(X_test)

# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Stay (0)', 'Leave (1)'])

# Plot confusion matrix
disp.plot(cmap='Blues')
plt.title("Confusion Matrix")
plt.show()

# Classification report
print("🔍 Classification Report:\n")
print(classification_report(y_test, y_pred, target_names=['Stay', 'Leave']))
# Out:
# 🔍 Classification Report:
#
#               precision    recall  f1-score   support
#
#         Stay       0.92      0.96      0.94       250
#        Leave       0.96      0.92      0.94       244
#
#     accuracy                           0.94       494
#    macro avg       0.94      0.94      0.94       494
# weighted avg       0.94      0.94      0.94       494

# %% [markdown]
# ## 🔍 Step 7: Interpret Results
#
# Use feature importance to identify the top factors affecting attrition. This helps HR focus on critical areas like OverTime, Income, and JobRole.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Get feature importances
importances = model.feature_importances_
features = X.columns

# Create DataFrame
importance_df = pd.DataFrame({
    'Feature': features,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

# Plot top 10
plt.figure(figsize=(10,6))
sns.barplot(x='Importance', y='Feature', data=importance_df.head(10))
plt.title("Top 10 Important Features Influencing Attrition")
plt.show()

# %% [markdown]
# ## ✅ Final Summary
#
# - Random Forest achieved the highest recall (~91%), making it suitable for predicting employee attrition.
# - Features like `OverTime`, `YearsAtCompany`, and `MonthlyIncome` strongly influence whether someone leaves.
# - This model can help HR teams identify at-risk employees and improve retention strategies.
